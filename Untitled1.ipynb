# %%
import pandas as pd

df = pd.read_excel('C:/Users/student/Downloads/10.xlsx')

df = df.drop_duplicates()           # удаляем дубликаты
df = df.dropna(how='all')           # удаляем полностью пустые строки
df = df.fillna('Нет данных')        # заполняем все пустые ячейки

df.to_excel('C:/Users/student/Downloads/очищенная.xlsx', index=False)
